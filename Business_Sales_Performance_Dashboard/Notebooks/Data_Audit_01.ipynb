# %% [markdown]
# # Business Sales Performance Analytics
# # Task 1 - Future Interns
# # Notebook 1 : Data Audit

# %%
import pandas as pd
import numpy as np

#Display settings
pd.set_option("display.max_columns",None)

# %%
df=pd.read_csv("../Dataset/Superstore.csv",encoding="ISO-8859-1")

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
print("Rows:",df.shape[0])
print("Columns:",df.shape[1])
# Out:
# Rows: 9994
# Columns: 21

# %%
df.columns.tolist()
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal Code',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
missing_values=df.isnull().sum()
missing_values[missing_values>0]
# Out:
# Series([], dtype: int64)

# %%
duplicates = df.duplicated().sum()
print("Duplicate Rows:",duplicates)
# Out:
# Duplicate Rows: 0

# %%
for col in df.columns:
    print(f"{col} : {df[col].nunique()}")
# Out:
# Row ID : 9994
# Order ID : 5009
# Order Date : 1237
# Ship Date : 1334
# Ship Mode : 4
# Customer ID : 793
# Customer Name : 793
# Segment : 3
# Country : 1
# City : 531
# State : 49
# Postal Code : 631
# Region : 4
# Product ID : 1862
# Category : 3
# Sub-Category : 17
# Product Name : 1850
# Sales : 5825
# Quantity : 14
# Discount : 12
# Profit : 7287

# %% [markdown]
# # Initial Observations
#
# ## Dataset Overview
#
# - The dataset contains 9,994 sales transaction records and 21 columns.
# - It includes transaction, customer, geographic, product, and sales-related information.
#
# ## Data Quality Assessment
#
# - No missing values were found.
# - No duplicate records were found.
# - The dataset is clean and suitable for analysis.
#
# ## Data Type Observations
#
# - Order Date and Ship Date are currently stored as object data types.
# - These columns will be converted to datetime format during the Data Cleaning phase to enable time-based analysis.
#
# ## Business-Relevant Features
#
# Key variables for analysis include:
#
# - Sales
# - Profit
# - Quantity
# - Discount
# - Category
# - Sub-Category
# - Region
# - State
# - Order Date
#
# ## Analytical Opportunities
#
# The dataset can be used to analyze:
#
# - Revenue trends over time
# - Product performance
# - Category performance
# - Regional sales and profitability
# - Impact of discounts on profit
#
# ## Next Steps
#
# Proceed to Data Cleaning and Feature Engineering.
